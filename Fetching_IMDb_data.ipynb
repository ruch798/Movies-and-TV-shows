# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
pip install imdbpy
# Out:
# ...
#      |████████████████████████████████| 296kB 4.9MB/s
# ...

# %%
fin_1 = pd.read_csv(r"drive/My Drive/Web scraper/Final/final.csv")
fin_1
# Out:
#        Unnamed: 0     ID                      Title  ...  Prime Video Disney+  Type
# 0               0      1               Breaking Bad  ...            0       0     1
# 1               1      2            Stranger Things  ...            0       0     1
# 2               2      3                Money Heist  ...            0       0     1
# 3               3      4                   Sherlock  ...            0       0     1
# 4               4      5           Better Call Saul  ...            0       0     1
# ...           ...    ...                        ...  ...          ...     ...   ...
# 22300       23860  23861  The Ghosts of Buxley Hall  ...            0       1     0
# 22301       23861  23862             The Poof Point  ...            0       1     0
# 22302       23862  23863      Sharks of Lost Island  ...            0       1     0
# 22303       23863  23864         Man Among Cheetahs  ...            0       1     0
# ...

# %%
fin_1.dtypes
# Out:
# Unnamed: 0           int64
# ID                  object
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes     object
# Netflix              int64
# Hulu                 int64
# Prime Video          int64
# Disney+              int64
# Type                 int64
# dtype: object

# %%
len(fin_1.index)
# Out:
# 22305

# %%
df2 = fin_1[fin_1.Type == 0]
df1 = df2[['Title',
'Year',
'Age',
'IMDb',
'Rotten Tomatoes',
'Netflix',
'Hulu',
'Prime Video',
'Disney+',
'Type']].copy()
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#                                 Title  Year  Age  ...  Prime Video Disney+  Type
# 0                           Inception  2010  13+  ...            0       0     0
# 1                          The Matrix  1999  18+  ...            0       0     0
# 2              Avengers: Infinity War  2018  13+  ...            0       0     0
# 3                  Back to the Future  1985   7+  ...            0       0     0
# 4      The Good, the Bad and the Ugly  1966  18+  ...            1       0     0
# ...                               ...   ...  ...  ...          ...     ...   ...
# 16739       The Ghosts of Buxley Hall  1980  NaN  ...            0       1     0
# 16740                  The Poof Point  2001   7+  ...            0       1     0
# 16741           Sharks of Lost Island  2013  NaN  ...            0       1     0
# 16742              Man Among Cheetahs  2017  NaN  ...            0       1     0
# 16743                In Beaver Valley  1950  NaN  ...            0       1     0
#
# ...

# %%
dataset1 = df1.loc[0:4186]
dataset1
# Out:
#                                Title  Year  Age  ...  Prime Video Disney+  Type
# 0                          Inception  2010  13+  ...            0       0     0
# 1                         The Matrix  1999  18+  ...            0       0     0
# 2             Avengers: Infinity War  2018  13+  ...            0       0     0
# 3                 Back to the Future  1985   7+  ...            0       0     0
# 4     The Good, the Bad and the Ugly  1966  18+  ...            1       0     0
# ...                              ...   ...  ...  ...          ...     ...   ...
# 4182                 Ismael's Ghosts  2017  18+  ...            0       0     0
# 4183                   The Challenge  2016  NaN  ...            0       0     0
# 4184                            Ride  2018  NaN  ...            2       0     0
# 4185                   Billboard Dad  1998  all  ...            0       0     0
# 4186                    American Gun  2005  18+  ...            0       0     0
#
# ...

# %%
dataset2 = df1.loc[4187:8372]
dataset2
# Out:
#                            Title  Year  Age  ...  Prime Video Disney+  Type
# 4187                Devil's Gate  2017  NaN  ...            0       0     0
# 4188        Contracted: Phase II  2015  NaN  ...            0       0     0
# 4189               Silent Tongue  1993  13+  ...            1       0     0
# 4190        Along Came the Devil  2018  16+  ...            0       0     0
# 4191               Status Update  2018  13+  ...            0       0     0
# ...                          ...   ...  ...  ...          ...     ...   ...
# 8368              Haunting Sarah  2005   7+  ...            1       0     0
# 8369  Steve-O: Guilty as Charged  2016  18+  ...            1       0     0
# 8370                    Bad Seed  2000  18+  ...            1       0     0
# 8371               Desert Riders  2012  NaN  ...            1       0     0
# 8372               Anonymous 616  2018  NaN  ...            1       0     0
#
# [4186 rows x 10 columns]

# %%
dataset3 = df1.loc[8373:12558]
dataset3
# Out:
#                                                    Title  Year  ... Disney+  Type
# 8373                                  Under Lock and Key  1995  ...       0     0
# 8374                                       Under the Bed  2012  ...       0     0
# 8375   You Belong to Me: Sex, Race and Murder in the ...  2015  ...       0     0
# 8376                             Love Between the Covers  2015  ...       0     0
# 8377                            The Beast And The Beauty  2005  ...       0     0
# ...                                                  ...   ...  ...     ...   ...
# 12554                                  The Brain Machine  1977  ...       0     0
# 12555                                        Sand Sharks  2011  ...       0     0
# 12556                                      Creature Lake  2015  ...       0     0
# 12557                                  The Funeral Guest  2015  ...       0     0
# ...

# %%
dataset4 = df1.loc[12559:16743]
dataset4
# Out:
#                             Title  Year  Age  ...  Prime Video Disney+  Type
# 12559    Fangs of the Living Dead  1969   7+  ...            1       0     0
# 12560  The Phantom of 42nd Street  1945  NaN  ...            1       0     0
# 12561            The Medicine Man  1930  NaN  ...            1       0     0
# 12562           Zedd: True Colors  2016  NaN  ...            1       0     0
# 12563        Broadway to Cheyenne  1932  all  ...            1       0     0
# ...                           ...   ...  ...  ...          ...     ...   ...
# 16739   The Ghosts of Buxley Hall  1980  NaN  ...            0       1     0
# 16740              The Poof Point  2001   7+  ...            0       1     0
# 16741       Sharks of Lost Island  2013  NaN  ...            0       1     0
# 16742          Man Among Cheetahs  2017  NaN  ...            0       1     0
# 16743            In Beaver Valley  1950  NaN  ...            0       1     0
#
# [4185 rows x 10 columns]

# %%
dataset5 = df1.loc[0:1]
dataset5
# Out:
#         Title  Year  Age  IMDb  ... Hulu  Prime Video  Disney+  Type
# 0   Inception  2010  13+   8.8  ...    0            0        0     0
# 1  The Matrix  1999  18+   8.7  ...    0            0        0     0
#
# [2 rows x 10 columns]

# %%
from imdb import IMDb
ia = IMDb()

# %%
i=0
count_id=0
count_d=0
count_g=0
# count_ca=0
count_co=0
count_l=0
count_r=0

m_director=[]
m_genre=[]
# m_cast=[]
m_country=[]
m_language=[]
m_runtime=[]
while(i<len(dataset2.index)):
    #  print(index, row,row.dtype)
  val_type = dataset2['Type'].values[i]
  if(val_type==0):
    val_movie = dataset2['Title'].values[i]
    # val_movie= "'%s'" % val_movie
    movies = ia.search_movie(val_movie)
    if(len(movies)!=0):
      movid = movies[0].movieID

      movie = ia.get_movie(movid)
      print(movie)

      movie_directors=""
      movie_genres=""
      # movie_cast=""
      movie_country=""
      movie_language=""
      movie_runtime=""
      c1=0
      c2=0
      # c3=0
      c4=0
      c5=0
      c6=0
      movid=int(movid)
      if(movid>0):
        count_id+=1;
        print(count_id)
        # print('Directors:')
        try:
          for director in movie['directors']:
            if(c1==0):
              count_d+=1
              movie_directors =director['name']
            
            else:
              movie_directors = movie_directors+","+ director['name']
            
            c1+=1
          m_director.append(movie_directors)
          # print(movie_directors)
        except:
          m_director.append("NA")
        

        # print('Genres:')
        try:
          for genre in movie['genres']:
            if(c2==0):
              count_g+=1
              movie_genres = genre

            else:
              movie_genres = movie_genres+"," +genre
            c2+=1
          m_genre.append(movie_genres)
          # print(movie_genres)
        except:
          m_genre.append("NA")
        
        # print('Cast:')
        # try:
        #   for cast in movie['cast']:
        #     if(c3==0):
        #       count_ca+=1
        #       movie_cast = cast

        #     else:
        #       movie_cast = movie_cast+"," +cast
        #     c3+=1
        #   m_cast.append(movie_cast)
        #   print(movie_cast)
        # except:
        #   m_cast.append("NA")
        
        # print('Countries:')
        try:
          for countries in movie['countries']:
            if(c4==0):
              count_co+=1
              movie_country = countries

            else:
              movie_country = movie_country+"," +countries
            c4+=1
          m_country.append(movie_country)
          # print(movie_country)
        except:
          m_country.append("NA")

        # print('Languages:') 
        try:
          for languages in movie['languages']:
            if(c5==0):
              count_l+=1
              movie_language = languages

            else:
              movie_language = movie_language+"," +languages
            c5+=1
          m_language.append(movie_language)
          # print(movie_language)
        except:
          m_language.append("NA")

        # print('Runtime:')
        try:
          for runtime in movie['runtimes']:
            if(c6==0):
              count_r+=1
              movie_runtime = runtime

            else:
              movie_runtime = movie_runtime+"," +runtime
            c6+=1
          m_runtime.append(movie_runtime)
          # print(movie_runtime)
        except:
          m_runtime.append("NA")
      else:
        a=1
    else:
        m_director.append("NA")
        m_genre.append("NA")
        # m_cast.append("NA")
        m_country.append("NA")
        m_language.append("NA")
        m_runtime.append("NA")
        a=1
  else:
    a=1
    # print('TV')
  i=i+1
# Out:
# Streaming output truncated to the last 5000 lines.
# 1680
# Tamjung Hong Gil-dong: Sarajin Ma-eul
# 1681
# Wheels on Meals
# 1682
# The Last Time I Saw Paris
# 1683
# Don't Talk to Irene
# 1684
# A Bad Idea Gone Wrong
# 1685
# Bottom of the 9th
# 1686
# Stop-Loss
# 1687
# Different for Girls
# 1688
# Absolutely Anything
# 1689
# Suture
# 1690
# Summer '03
# 1691
# Chopping Mall
# 1692
# Sin Nombre
# 1693
# The Legend of Bhagat Singh
# 1694
# Felony
# 1695
# Elián
# 1696
# The Price We Pay
# 1697
# Bad Blood: The Movie
# 1698
# Red Lights
# 1699
# Calling All Earthlings
# 1700
# Exam
# 1701
# Mowgli: Legend of the Jungle
# 1702
# Twilight
# 1703
# Bravetown
# 1704
# The Creeping Flesh
# 1705
# Derailroaded
# 1706
# Lies and Alibis
# 1707
# Infinity Baby
# 1708
# Bruce Lee: A Warrior's Journey
# 1709
# The Journey
# 1710
# Gogol Bordello Non-Stop
# 1711
# Bad Milo
# 1712
# Feast of Love
# 1713
# Under the Gun
# 1714
# George Carlin: Complaints & Grievances
# 1715
# Parked
# 1716
# ...

# %%
# fin = {'First_name': ['Ram', 'Mohan'],  
#                 'Last_name': ['Kumar', 'Sharma'],  
#                 'Marks': [12, 52] } 
# fin['Cast'] = m_cast
dataset2['Directors'] = m_director
dataset2['Genres'] = m_genre
dataset2['Country'] = m_country
dataset2['Language'] = m_language
dataset2['Runtime'] = m_runtime
# fin
# df3 = pd.DataFrame(fin)
dataset2
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dataset2.to_csv(r"drive/My Drive/Web scraper/Datasets/f2.csv")

# %%
count_id

# %%
count_d

# %%
count_g

# %%
movies = ia.search_movie('Inception90909')
movid = movies[0].movieID

movie = ia.get_movie(movid)
movie_directors=""
movie_genres=""
c1=0
c2=0
print(movie)
print(movid)
print('Directors:')
for director in movie['directors']:
  if(c1==0):
      movie_directors =director['name']
  
  else:
      movie_directors = movie_directors+","+ director['name']
  
  c1+=1
  print(director['name'])
print('Genres:')
for genre in movie['genres']:
  if(c2==0):
      movie_genres = genre
  
  else:
      movie_genres = movie_genres+"," +genre
  c2+=1
  print(genre)

# %%
print(movie_directors)
print(movie_genres)

# %%
d1 = pd.read_csv(r"drive/My Drive/Web scraper/Datasets/f1.csv")
d2 = pd.read_csv(r"drive/My Drive/Web scraper/Datasets/f2.csv")
d3 = pd.read_csv(r"drive/My Drive/Web scraper/Datasets/f3.csv")
d4 = pd.read_csv(r"drive/My Drive/Web scraper/Datasets/f4.csv")

# %%
frames = [d1,d2,d3,d4]
merged = pd.concat(frames)

# %%
merged
# Out:
#       Unnamed: 0  ... Runtime
# 0              0  ...   148.0
# 1              1  ...   136.0
# 2              2  ...   149.0
# 3              3  ...   116.0
# 4              4  ...   161.0
# ...          ...  ...     ...
# 4180       16739  ...   120.0
# 4181       16740  ...    90.0
# 4182       16741  ...     NaN
# 4183       16742  ...     NaN
# 4184       16743  ...    32.0
#
# [16744 rows x 16 columns]

# %%
merged.reset_index(drop=True, inplace=True)
merged
# Out:
#        Unnamed: 0  ... Runtime
# 0               0  ...   148.0
# 1               1  ...   136.0
# 2               2  ...   149.0
# 3               3  ...   116.0
# 4               4  ...   161.0
# ...           ...  ...     ...
# 16739       16739  ...   120.0
# 16740       16740  ...    90.0
# 16741       16741  ...     NaN
# 16742       16742  ...     NaN
# 16743       16743  ...    32.0
#
# [16744 rows x 16 columns]

# %%
merged__df = merged[['Title',
'Year',
'Age',
'IMDb',
'Rotten Tomatoes',
'Netflix',
'Hulu',
'Prime Video',
'Disney+',
'Type',
'Directors',
'Genres',
'Country',
'Language',
'Runtime']].copy()

# %%
merged_df
# Out:
#        Unnamed: 0  ... Runtime
# 0               0  ...   148.0
# 1               1  ...   136.0
# 2               2  ...   149.0
# 3               3  ...   116.0
# 4               4  ...   161.0
# ...           ...  ...     ...
# 16739       16739  ...   120.0
# 16740       16740  ...    90.0
# 16741       16741  ...     NaN
# 16742       16742  ...     NaN
# 16743       16743  ...    32.0
#
# [16744 rows x 16 columns]

# %%
merged_df.insert(0, 'ID', range(1, 1 + len(merged_df)))

# %%
for col in merged_df.columns: 
    print(col)
# Out:
# ID
# Unnamed: 0
# Title
# Year
# Age
# IMDb
# Rotten Tomatoes
# Netflix
# Hulu
# Prime Video
# Disney+
# Type
# Directors
# Genres
# Country
# Language
# Runtime

# %%
merged_df = merged_df.drop(['Unnamed: 0'], axis=1)

# %%
merged_df.to_csv(r"drive/My Drive/Web scraper/Datasets/dataset.csv")

# %%
merged_df.isnull().sum()
# Out:
# ID                     0
# Title                  0
# Year                   0
# Age                 9390
# IMDb                 571
# Rotten Tomatoes    11586
# Netflix                0
# Hulu                   0
# Prime Video            0
# Disney+                0
# Type                   0
# Directors            726
# Genres               275
# Country              435
# Language             599
# Runtime              592
# dtype: int64
